# %%
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as soup
import datetime
import json
import requests

# %%
leaderboard_df = pd.read_csv('Leaderboard2.csv')

# %%
leaderboard_df
# Out:
#      Unnamed: 0   rank  seasons  titlesWon  leaguesWon  divsWon1  divsWon2  \
# 0             0  12002      294        271         262         2         4
# 1             1  11530      189        114         105         2         4
# 2             2  11507      223        207         198         2         4
# 3             3  11309      294        162         150         5         4
# 4             4  11184     1175        709         678        24         4
# ..          ...    ...      ...        ...         ...       ...       ...
# 463         463   8118       75         50          41         2         4
# 464         464   8101      248         69          47        13         7
# 465         465   8099       46         15           4         5         3
# 466         466   8077      125         39          25         8         3
# 467         467   8072       62         29          20         1         5
#
#      divsWon3  cupsWon6  cupsWon5  ...  averageGoalsAgainstPerGame  \
# 0           3         0         0  ...                        0.52
# 1           3         0         0  ...                        0.73
# 2           3         1         0  ...                        0.69
# 3           3         0         0  ...                        1.06
# 4           3         2         0  ...                        1.19
# ..        ...       ...       ...  ...                         ...
# 463         3         0         0  ...                        1.21
# 464         2         2         0  ...                        1.92
# 465         3         0         0  ...                        1.35
# 466         3         1         0  ...                        1.70
# 467         3         0         0  ...                        1.46
#
#      cleanSheets  starLevel  agreggateRecord         clubName   clubId  \
# 0              0         10     2248-178-121          Tiki XI  2370013
# 1              0         10     1238-221-222      MIA SAN MIA    16973
# 2              0         10     1701-136-107   I JINCHURIKI I  1523768
# 3              0         10     1892-321-438     xXCECIFOOTXx  3498998
# 4              0         10   7799-1098-1731    The Champions    18353
# ..           ...        ...              ...              ...      ...
# 463            0         10        501-63-91           Toplam  6374523
# 464            0         10     1267-353-665       COLE WORLD   829988
# 465            0          9       213-77-133          Seiseki    11818
# 466            0         10      658-189-292      Siirt Jetpa   198183
# 467            0         10       367-57-125  SlowLife Esport  8967548
#
#      currentDivision  rankingPoints  \
# 0                 10          12002
# 1                 10          11530
# 2                 10          11507
# 3                 10          11309
# 4                 10          11184
# ..               ...            ...
# 463               10           8118
# 464               10           8101
# 465               10           8099
# 466               10           8077
# 467               10           8072
#
#                                               clubInfo  platform
# 0    {'name': 'Tiki XI', 'clubId': 2370013, 'region...       ps5
# 1    {'name': 'MIA SAN MIA', 'clubId': 16973, 'regi...       ps5
# 2    {'name': 'I JINCHURIKI I', 'clubId': 1523768, ...       ps5
# 3    {'name': 'xXCECIFOOTXx', 'clubId': 3498998, 'r...       ps5
# 4    {'name': 'The Champions', 'clubId': 18353, 're...       ps5
# ..                                                 ...       ...
# 463  {'name': 'Toplam', 'clubId': 6374523, 'regionI...        pc
# 464  {'name': 'COLE WORLD', 'clubId': 829988, 'regi...        pc
# 465  {'name': 'Seiseki', 'clubId': 11818, 'regionId...        pc
# 466  {'name': 'Siirt Jetpa', 'clubId': 198183, 'reg...        pc
# 467  {'name': 'SlowLife Esport', 'clubId': 8967548,...        pc
#
# [468 rows x 37 columns]

# %%
leaderboard_df = leaderboard_df[["clubId", "platform"]]
leaderboard_df
# Out:
#       clubId platform
# 0    2370013      ps5
# 1      16973      ps5
# 2    1523768      ps5
# 3    3498998      ps5
# 4      18353      ps5
# ..       ...      ...
# 463  6374523       pc
# 464   829988       pc
# 465    11818       pc
# 466   198183       pc
# 467  8967548       pc
#
# [468 rows x 2 columns]

# %%
def match_overview_data_assign(json_dict):
    result = []

    for game in json_dict:
        match_dict = {
            'matchId': game['matchId'],
            'timestamp': datetime.datetime.utcfromtimestamp(game['timestamp']).strftime('%Y-%m-%d %H:%M:%S UTC'),
        }

        both_club_data = game['clubs']

        # Iterate through team data directly
        for team_prefix, data in both_club_data.items():
            prefix = f'team_{team_prefix}'  # Create a dynamic prefix

            for key, value in data.items():
                if key == 'details':
                    match_dict[f'{prefix}_{key}_name'] = value['name']
                    match_dict[f'{prefix}_{key}_clubId'] = str(value['clubId'])
                    match_dict[f'{prefix}_{key}_regionId'] = str(value['regionId'])
                    match_dict[f'{prefix}_{key}_teamId'] = str(value['teamId'])
                    match_dict[f'{prefix}_{key}_stadName'] = value['customKit']['stadName']
                    match_dict[f'{prefix}_{key}_isCustomTeam'] = str(value['customKit']['isCustomTeam'])
                else:
                    match_dict[f'{prefix}_{key}'] = str(value)

        result.append(match_dict)

    return result

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
match_overview_dictionary = []

# %%
# Iterate through the rows of leaderboard_df
for index, row in leaderboard_df.iterrows():
    # Construct the URL based on clubId and platform
    club_id = row['clubId']
    platform = row['platform']
    url = f"https://proclubs.ea.com/api/fifa/clubs/matches?matchType=gameType9&platform={platform}&clubIds={club_id}"
    
    try:
        browser.visit(url)
        site = soup(browser.html, "html.parser")

        # Find the <pre> tag containing the JSON data
        pre_tag = site.find('pre')

        if pre_tag:
            # Extract the JSON data from the <pre> tag
            json_data = pre_tag.text

            # Convert JSON to a Python dictionary
            json_dict = json.loads(json_data)

            # Extract the broad match data and extend the list
            match_overview_dictionary.extend(match_overview_data_assign(json_dict))

    # Now, match_overview_dictionary contains match data from all the URLs in leaderboard_df
    except: 
        pass

# %%
browser.quit()

# %%
match_overview_dictionary_df = pd.DataFrame(match_overview_dictionary)

# %%
match_overview_dictionary_df
# Out:
#               matchId                timestamp team_2370013_gameNumber  \
# 0     113416222460126  2023-08-04 22:19:02 UTC                       2
# 1     113362832250328  2023-08-04 21:58:52 UTC                       1
# 2     113360773520152  2023-08-04 21:40:59 UTC                       0
# 3     113408104240267  2023-08-04 21:18:31 UTC                       7
# 4     113344746940365  2023-08-04 20:57:51 UTC                       6
